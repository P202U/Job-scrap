# %% [markdown]
# <a href="https://colab.research.google.com/github/P202U/Job-scrap/blob/main/Job_Scrap_0_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import random
from concurrent.futures import ThreadPoolExecutor

# %%
keyword = 'fullstack'
location = 'Mumbai'
pageNum = 0
job_url = f'https://www.linkedin.com/jobs/search?keywords={keyword}&location={location}&pageNum={pageNum}'

response = requests.get(job_url)
job_data = response.text
soup = BeautifulSoup(job_data, "lxml")
page_jobs = soup.find_all('div', {'class': 'base-card relative w-full hover:no-underline focus:no-underline base-card--link base-search-card base-search-card--link job-search-card'})

# %%
job_id_list = []

page_jobs = soup.find_all('div', class_='job-search-card')

for job_card in page_jobs:
    try:
        urn_string = job_card.get("data-entity-urn")

        if urn_string:
            job_id = urn_string.split(":")[-1]

            print(job_id)
            job_id_list.append(job_id)

    except (AttributeError, IndexError) as e:
        print(f"Skipping a job card due to an error: {e}")
        continue

print("\nAll extracted Job IDs:", job_id_list)
# Out:
# 4290796891
# 4259114971
# 4220839450
# 3849501886
# 3627622884
# 4292967130
# 4260012242
# 4255094324
# 4259098167
# 4259116372
# 4048230355
# 4276958556
# 4273221487
# 4240914500
# 4281485208
# 4287361545
# 4275350664
# 4168111890
# 4294061622
# 4244771461
# 4258065248
# 4267461418
# 4282530309
# 4204756249
# 4240915365
# 4295334909
# 4048228635
# 4261493690
# 4278553667
# 4282834220
# 4274643866
# 4274641859
# 4259095678
# 4293772062
# 4193362955
# 4292567427
# 4190532210
# 4189885322
# 4294838113
# 4273381368
# 4273385083
# 4273386060
# 4263992402
# 4273384149
# 4291154278
# 4281093212
# 4295167685
# 4273379435
# 4273379444
# 4273386061
# 4273381377
# 4273382291
# 4287397373
# 4281091343
# 4273380382
# 4273378985
# 4267225737
# 4255398471
# 4294396741
# 4273385077
#
# All extracted Job IDs: ['4290796891', '4259114971', '4220839450', '3849501886', '3627622884', '4292967130', '4260012242', '4255094324', '4259098167', '4259116372', '4048230355', '4276958556', '4273221487', '4240914500', '4281485208', '4287361545', '4275350664', '4168111890', '4294061622', '4244771461', '4258065248', '4267461418', '4282530309', '4204756249', '4240915365', '4295334909', '4048228635', '4261493690', '4278553667', '4282834220', '4274643866', '4274641859', '4259095678', '4293772062', '4193362955', '4292567427', '4190532210', '4189885322', '4294838113', '4273381368', '4273385083', '4273386060', '4263992402', '4273384149', '4291154278', '4281093212', '4295167685', '4273379435', '4273379444', '4273386061', '4273381377', '4273382291', '4287397373', '4281091343', '4273380382', '4273378985', '4267225737', '4255398471', '4294396741', '4273385077']

# %%
job_list = []

def scrape_job(job_id):
    job_url = f"https://www.linkedin.com/jobs-guest/jobs/api/jobPosting/{job_id}"

    try:
        # Use a user-agent to mimic a browser, making the request less likely to be blocked.
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
        }
        job_response = requests.get(job_url, headers=headers)
        job_response.raise_for_status()
        job_soup = BeautifulSoup(job_response.text, "lxml")

        # Extraction logic
        job_post = {
        "time_posted": None,
        "company_name": None,
        "job_title": None,
        "num_applicants": None,
        "job_id": job_id
    }

        title_element = job_soup.select_one("h2.topcard__title")
        if title_element:
            job_post["job_title"] = title_element.get_text(strip=True)

        company_element = job_soup.select_one("a.topcard__org-name-link")
        if company_element:
            job_post["company_name"] = company_element.get_text(strip=True)

        time_element = job_soup.select_one("span.posted-time-ago__text")
        if time_element:
            job_post["time_posted"] = time_element.get_text(strip=True)

        applicants_element = job_soup.select_one("figcaption.num-applicants__caption")
        if not applicants_element:
            applicants_element = job_soup.select_one("span.num-applicants__caption")

        if applicants_element:
            applicants_text = applicants_element.get_text(strip=True)
            # Use regular expressions to extract only the numerical value
            import re
            match = re.search(r'\d+', applicants_text)
            if match:
                job_post["num_applicants"] = int(match.group())
            else:
                job_post["num_applicants"] = applicants_text

        print(f"Successfully fetched job posting {job_id}")
        return job_post

    except requests.exceptions.RequestException as e:
        print(f"Failed to fetch job posting {job_id}: {e}")
        return None

    finally:
        # To mimic human behaviour
        time.sleep(random.uniform(2, 5))

with ThreadPoolExecutor(max_workers=5) as executor:
    results = executor.map(scrape_job, job_id_list)
    for result in results:
        if result:
            job_list.append(result)

print("Scraping complete.")
# Out:
# Scraping complete.

# %%
job_list
# Out:
# [{'time_posted': '6 days ago',
#   'company_name': 'Ventura',
#   'job_title': 'Full Stack Developer',
#   'num_applicants': 200,
#   'job_id': '4290796891'},
#  {'time_posted': '2 months ago',
#   'company_name': 'Fynd',
#   'job_title': 'SDE - 1 | Fullstack Developer',
#   'num_applicants': 200,
#   'job_id': '4259114971'},
#  {'time_posted': '4 months ago',
#   'company_name': 'Softlink Global',
#   'job_title': 'Fullstack Developer (0-3 years)',
#   'num_applicants': 200,
#   'job_id': '4220839450'},
#  {'time_posted': '1 year ago',
#   'company_name': 'Dimensionless Technologies',
#   'job_title': 'Fullstack / Mern stack Developer',
#   'num_applicants': 25,
#   'job_id': '3849501886'},
#  {'time_posted': '2 years ago',
#   'company_name': 'UnFound',
#   'job_title': 'Fullstack Developer',
#   'num_applicants': 25,
#   'job_id': '3627622884'},
#  {'time_posted': '5 days ago',
#   'company_name': 'AuxoAI',
#   'job_title': 'Fullstack Engineer',
#   'num_applicants': 182,
#   'job_id': '4292967130'},
#  {'time_posted': '2 months ago',
#   'company_name': 'Talent Worx',
#   'job_title': 'Fullstack Developer',
#   'num_applicants': 25,
#   'job_id': '4260012242'},
#  {'time_posted': '2 months ago',
#   'company_name': 'Fynd',
#   'job_title': 'Fullstack Developer | Gauze',
#   'num_applicants': 97,
#   'job_id': '4255094324'},
#  {'time_posted': '2 months ago',
#   'company_name': 'Workduck',
#   'job_title': 'SDE - II (Full Stack Developer)',
#   'num_applicants': 136,
#   'job_id': '4259098167'},
#  {'time_posted': '2 months ago',
#   'company_name': 'Fynd',
#   'job_title': 'SDE - 2 | Fullstack Developer',
#   'num_applicants': 146,
#   'job_id': '4259116372'},
#  {'time_posted': '10 months ago',
#   'company_name': 'Enago (Crimson Interactive)',
#   'job_title': 'Backend Fullstack Developer',
#   'num_applicants': 92,
#   'job_id': '4048230355'},
#  {'time_posted': '1 month ago',
#   'company_name': 'NEC Software Solutions (India)',
#   'job_title': 'Consultant - Fullstack - NodeJs, React/ Angular',
#   'num_applicants': 89,
#   'job_id': '4276958556'},
#  {'time_posted': '1 month ago',
#   'company_name': 'NEC Software Solutions',
#   'job_title': 'Consultant - Fullstack - NodeJs, React/ Angular',
#   'num_applicants': 116,
#   'job_id': '4273221487'},
#  {'time_posted': '3 months ago',
#   'company_name': 'The Fast Way',
#   'job_title': 'Full Stack Developer',
#   'num_applicants': 143,
#   'job_id': '4240914500'},
#  {'time_posted': '1 month ago',
#   'company_name': 'Antarctica',
#   'job_title': 'Junior Fullstack Developer (Node/React)',
#   'num_applicants': 25,
#   'job_id': '4281485208'},
#  {'time_posted': '1 month ago',
#   'company_name': 'CGF CounselGroupFrankfurt AG',
#   'job_title': 'Full-Stack Developer',
#   'num_applicants': 25,
#   'job_id': '4287361545'},
#  {'time_posted': '2 weeks ago',
#   'company_name': 'PivotRoots',
#   'job_title': 'Backend Developer',
#   'num_applicants': 200,
#   'job_id': '4275350664'},
#  {'time_posted': '6 months ago',
#   'company_name': 'Fynd',
#   'job_title': 'SDE 3 - FullStack | Node.js | React.js',
#   'num_applicants': 200,
#   'job_id': '4168111890'},
#  {'time_posted': '2 days ago',
#   'company_name': 'Affinity Global Inc.',
#   'job_title': 'Software Engineer, Web Development',
#   'num_applicants': 77,
#   'job_id': '4294061622'},
#  {'time_posted': '2 months ago',
#   'company_name': 'PriceLabs',
#   'job_title': 'Full Stack Engineer - II (Remote)',
#   'num_applicants': 200,
#   'job_id': '4244771461'},
#  {'time_posted': '2 months ago',
#   'company_name': 'BairesDev',
#   'job_title': 'Fullstack Javascript Engineer (React + Node) - Remote Work | REF#283290',
#   'num_applicants': 161,
#   'job_id': '4258065248'},
#  {'time_posted': '5 days ago',
#   'company_name': 'MSCI Inc.',
#   'job_title': 'Fullstack Developer',
#   'num_applicants': 162,
#   'job_id': '4267461418'},
#  {'time_posted': '1 month ago',
#   'company_name': 'Antarctica',
#   'job_title': 'Junior Backend Developer (Node.JS)',
#   'num_applicants': 25,
#   'job_id': '4282530309'},
#  {'time_posted': '4 months ago',
#   'company_name': 'VRSamadhan',
#   'job_title': 'Fullstack Developer - MLK\nInformation Technology,',
#   'num_applicants': 28,
#   'job_id': '4204756249'},
#  {'time_posted': '3 months ago',
#   'company_name': 'Axioned',
#   'job_title': 'Fullstack Engineer',
#   'num_applicants': 35,
#   'job_id': '4240915365'},
#  {'time_posted': '48 minutes ago',
#   'company_name': 'Wits Innovation Lab',
#   'job_title': 'FullStack Engineer',
#   'num_applicants': 33,
#   'job_id': '4295334909'},
#  {'time_posted': '10 months ago',
#   'company_name': 'Enago (Crimson Interactive)',
#   'job_title': 'SDE-3 Fullstack (VueJs-NodeJs)',
#   'num_applicants': 25,
#   'job_id': '4048228635'},
#  {'time_posted': '2 months ago',
#   'company_name': 'Wama Technology Pvt Ltd  - Providing Staff Augmentation, Software Solutions Globally',
#   'job_title': 'Full Stack Developer',
#   'num_applicants': 82,
#   'job_id': '4261493690'},
#  {'time_posted': '1 week ago',
#   'company_name': 'BlackRock',
#   'job_title': 'Fullstack Developer, Aladdin Engineering, Associate',
#   'num_applicants': 200,
#   'job_id': '4278553667'},
#  {'time_posted': '2 weeks ago',
#   'company_name': 'FlexiLoans',
#   'job_title': 'Fullstack Engineer â III & IV',
#   'num_applicants': 25,
#   'job_id': '4282834220'},
#  {'time_posted': '1 week ago',
#   'company_name': 'PwC Acceleration Center India',
#   'job_title': 'Manager, Software Engineering',
#   'num_applicants': 56,
#   'job_id': '4274643866'},
#  {'time_posted': '1 week ago',
#   'company_name': 'PwC Acceleration Center India',
#   'job_title': 'Manager, Software Engineering',
#   'num_applicants': 62,
#   'job_id': '4274641859'},
#  {'time_posted': '2 months ago',
#   'company_name': 'Exponentia.ai',
#   'job_title': 'Full Stack Developer (React + Python)',
#   'num_applicants': 55,
#   'job_id': '4259095678'},
#  {'time_posted': '3 days ago',
#   'company_name': 'Sodexo',
#   'job_title': 'Sitecore - Tech Lead',
#   'num_applicants': 36,
#   'job_id': '4293772062'},
#  {'time_posted': '5 months ago',
#   'company_name': 'NEC Software Solutions (India)',
#   'job_title': 'Senior Software Engineer - Sr Fullstack Developer',
#   'num_applicants': 50,
#   'job_id': '4193362955'},
#  {'time_posted': '1 week ago',
#   'company_name': 'Semble',
#   'job_title': 'Senior Fullstack Software Engineer',
#   'num_applicants': 25,
#   'job_id': '4292567427'},
#  {'time_posted': '5 months ago',
#   'company_name': 'Fynd',
#   'job_title': 'SDE 3 - Python Fullstack',
#   'num_applicants': 60,
#   'job_id': '4190532210'},
#  {'time_posted': '5 months ago',
#   'company_name': 'BairesDev',
#   'job_title': 'Fullstack Python Developer - Remote Work | REF#282828',
#   'num_applicants': 50,
#   'job_id': '4189885322'},
#  {'time_posted': '19 hours ago',
#   'company_name': 'IIT Bombay',
#   'job_title': 'Fullstack Developer',
#   'num_applicants': 88,
#   'job_id': '4294838113'},
#  {'time_posted': '2 weeks ago',
#   'company_name': 'Turing',
#   'job_title': 'Remote Fullstack Engineer',
#   'num_applicants': 25,
#   'job_id': '4273381368'},
#  {'time_posted': '2 weeks ago',
#   'company_name': 'Turing',
#   'job_title': 'Remote Fullstack Engineer',
#   'num_applicants': 25,
#   'job_id': '4273385083'},
#  {'time_posted': '2 weeks ago',
#   'company_name': 'Turing',
#   'job_title': 'Remote Fullstack Engineer',
#   'num_applicants': 25,
#   'job_id': '4273386060'},
#  {'time_posted': '1 month ago',
#   'company_name': 'Onclusive',
#   'job_title': 'Full Stack Engineer',
#   'num_applicants': 200,
#   'job_id': '4263992402'},
#  {'time_posted': '2 weeks ago',
#   'company_name': 'Turing',
#   'job_title': 'Remote Fullstack Engineer',
#   'num_applicants': 25,
#   'job_id': '4273384149'},
#  {'time_posted': '5 days ago',
#   'company_name': 'WeAssemble',
#   'job_title': 'Fullstack PHP Developer',
#   'num_applicants': 27,
#   'job_id': '4291154278'},
#  {'time_posted': '2 days ago',
#   'company_name': 'PwC Acceleration Center India',
#   'job_title': 'Engineering Manager',
#   'num_applicants': 36,
#   'job_id': '4281093212'},
#  {'time_posted': '5 hours ago',
#   'company_name': 'Privacy Pillar',
#   'job_title': 'FullStack Engineer  |  5 Years Experience',
#   'num_applicants': 25,
#   'job_id': '4295167685'},
#  {'time_posted': '2 weeks ago',
#   'company_name': 'Turing',
#   'job_title': 'Remote Fullstack Engineer',
#   'num_applicants': 25,
#   'job_id': '4273379435'},
#  {'time_posted': '2 weeks ago',
#   'company_name': 'Turing',
#   'job_title': 'Remote Fullstack Engineer',
#   'num_applicants': 25,
#   'job_id': '4273379444'},
#  {'time_posted': '2 weeks ago',
#   'company_name': 'Turing',
#   'job_title': 'Remote Fullstack Engineer',
#   'num_applicants': 25,
#   'job_id': '4273386061'},
#  {'time_posted': '2 weeks ago',
#   'company_name': 'Turing',
#   'job_title': 'Remote Fullstack Engineer',
#   'num_applicants': 25,
#   'job_id': '4273381377'},
#  {'time_posted': '2 weeks ago',
#   'company_name': 'Turing',
#   'job_title': 'Remote Fullstack Engineer',
#   'num_applicants': 25,
#   'job_id': '4273382291'},
#  {'time_posted': '2 weeks ago',
#   'company_name': 'Russell Investments',
#   'job_title': 'Developer II',
#   'num_applicants': 60,
#   'job_id': '4287397373'},
#  {'time_posted': '2 days ago',
#   'company_name': 'PwC Acceleration Center India',
#   'job_title': 'Engineering Manager',
#   'num_applicants': 33,
#   'job_id': '4281091343'},
#  {'time_posted': '2 weeks ago',
#   'company_name': 'Turing',
#   'job_title': 'Remote Fullstack Engineer',
#   'num_applicants': 25,
#   'job_id': '4273380382'},
#  {'time_posted': '2 weeks ago',
#   'company_name': 'Turing',
#   'job_title': 'Remote Fullstack Engineer',
#   'num_applicants': 25,
#   'job_id': '4273378985'},
#  {'time_posted': '1 month ago',
#   'company_name': 'Interactive Brokers',
#   'job_title': 'Software Engineer - Java Fullstack',
#   'num_applicants': 124,
#   'job_id': '4267225737'},
#  {'time_posted': '2 months ago',
#   'company_name': 'iCanHeal',
#   'job_title': 'iCanHeal - Python Full Stack Developer - Django/Javascript',
#   'num_applicants': 54,
#   'job_id': '4255398471'},
#  {'time_posted': '1 day ago',
#   'company_name': 'JPMorganChase',
#   'job_title': 'Software Engineer II - Java Fullstack (web/Mobile), AWS',
#   'num_applicants': 79,
#   'job_id': '4294396741'},
#  {'time_posted': '2 weeks ago',
#   'company_name': 'Turing',
#   'job_title': 'Remote Fullstack Engineer',
#   'num_applicants': 25,
#   'job_id': '4273385077'}]

# %%
jobs_df = pd.DataFrame(job_list)
jobs_df
# Out:
#        time_posted                                       company_name  \
# 0       6 days ago                                            Ventura
# 1     2 months ago                                               Fynd
# 2     4 months ago                                    Softlink Global
# 3       1 year ago                         Dimensionless Technologies
# 4      2 years ago                                            UnFound
# 5       5 days ago                                             AuxoAI
# 6     2 months ago                                        Talent Worx
# 7     2 months ago                                               Fynd
# 8     2 months ago                                           Workduck
# 9     2 months ago                                               Fynd
# 10   10 months ago                        Enago (Crimson Interactive)
# 11     1 month ago                     NEC Software Solutions (India)
# 12     1 month ago                             NEC Software Solutions
# 13    3 months ago                                       The Fast Way
# 14     1 month ago                                         Antarctica
# 15     1 month ago                       CGF CounselGroupFrankfurt AG
# 16     2 weeks ago                                         PivotRoots
# 17    6 months ago                                               Fynd
# 18      2 days ago                               Affinity Global Inc.
# 19    2 months ago                                          PriceLabs
# 20    2 months ago                                          BairesDev
# 21      5 days ago                                          MSCI Inc.
# 22     1 month ago                                         Antarctica
# 23    4 months ago                                         VRSamadhan
# 24    3 months ago                                            Axioned
# 25  48 minutes ago                                Wits Innovation Lab
# 26   10 months ago                        Enago (Crimson Interactive)
# 27    2 months ago  Wama Technology Pvt Ltd  - Providing Staff Aug...
# 28      1 week ago                                          BlackRock
# 29     2 weeks ago                                         FlexiLoans
# 30      1 week ago                      PwC Acceleration Center India
# 31      1 week ago                      PwC Acceleration Center India
# 32    2 months ago                                      Exponentia.ai
# 33      3 days ago                                             Sodexo
# 34    5 months ago                     NEC Software Solutions (India)
# 35      1 week ago                                             Semble
# 36    5 months ago                                               Fynd
# 37    5 months ago                                          BairesDev
# 38    19 hours ago                                         IIT Bombay
# 39     2 weeks ago                                             Turing
# 40     2 weeks ago                                             Turing
# 41     2 weeks ago                                             Turing
# 42     1 month ago                                          Onclusive
# 43     2 weeks ago                                             Turing
# 44      5 days ago                                         WeAssemble
# 45      2 days ago                      PwC Acceleration Center India
# 46     5 hours ago                                     Privacy Pillar
# 47     2 weeks ago                                             Turing
# 48     2 weeks ago                                             Turing
# 49     2 weeks ago                                             Turing
# 50     2 weeks ago                                             Turing
# 51     2 weeks ago                                             Turing
# 52     2 weeks ago                                Russell Investments
# 53      2 days ago                      PwC Acceleration Center India
# 54     2 weeks ago                                             Turing
# 55     2 weeks ago                                             Turing
# 56     1 month ago                                Interactive Brokers
# 57    2 months ago                                           iCanHeal
# 58       1 day ago                                      JPMorganChase
# 59     2 weeks ago                                             Turing
#
#                                             job_title  num_applicants  \
# 0                                Full Stack Developer             200
# 1                       SDE - 1 | Fullstack Developer             200
# 2                     Fullstack Developer (0-3 years)             200
# 3                    Fullstack / Mern stack Developer              25
# 4                                 Fullstack Developer              25
# 5                                  Fullstack Engineer             182
# 6                                 Fullstack Developer              25
# 7                         Fullstack Developer | Gauze              97
# 8                     SDE - II (Full Stack Developer)             136
# 9                       SDE - 2 | Fullstack Developer             146
# 10                        Backend Fullstack Developer              92
# 11    Consultant - Fullstack - NodeJs, React/ Angular              89
# 12    Consultant - Fullstack - NodeJs, React/ Angular             116
# 13                               Full Stack Developer             143
# 14            Junior Fullstack Developer (Node/React)              25
# 15                               Full-Stack Developer              25
# 16                                  Backend Developer             200
# 17             SDE 3 - FullStack | Node.js | React.js             200
# 18                 Software Engineer, Web Development              77
# 19                  Full Stack Engineer - II (Remote)             200
# 20  Fullstack Javascript Engineer (React + Node) -...             161
# 21                                Fullstack Developer             162
# 22                 Junior Backend Developer (Node.JS)              25
# 23  Fullstack Developer - MLK\nInformation Technol...              28
# 24                                 Fullstack Engineer              35
# 25                                 FullStack Engineer              33
# 26                     SDE-3 Fullstack (VueJs-NodeJs)              25
# 27                               Full Stack Developer              82
# 28  Fullstack Developer, Aladdin Engineering, Asso...             200
# 29                      Fullstack Engineer â III & IV              25
# 30                      Manager, Software Engineering              56
# 31                      Manager, Software Engineering              62
# 32              Full Stack Developer (React + Python)              55
# 33                               Sitecore - Tech Lead              36
# 34  Senior Software Engineer - Sr Fullstack Developer              50
# 35                 Senior Fullstack Software Engineer              25
# 36                           SDE 3 - Python Fullstack              60
# 37  Fullstack Python Developer - Remote Work | REF...              50
# 38                                Fullstack Developer              88
# 39                          Remote Fullstack Engineer              25
# 40                          Remote Fullstack Engineer              25
# 41                          Remote Fullstack Engineer              25
# 42                                Full Stack Engineer             200
# 43                          Remote Fullstack Engineer              25
# 44                            Fullstack PHP Developer              27
# 45                                Engineering Manager              36
# 46          FullStack Engineer  |  5 Years Experience              25
# 47                          Remote Fullstack Engineer              25
# 48                          Remote Fullstack Engineer              25
# 49                          Remote Fullstack Engineer              25
# 50                          Remote Fullstack Engineer              25
# 51                          Remote Fullstack Engineer              25
# 52                                       Developer II              60
# 53                                Engineering Manager              33
# 54                          Remote Fullstack Engineer              25
# 55                          Remote Fullstack Engineer              25
# 56                 Software Engineer - Java Fullstack             124
# 57  iCanHeal - Python Full Stack Developer - Djang...              54
# 58  Software Engineer II - Java Fullstack (web/Mob...              79
# 59                          Remote Fullstack Engineer              25
#
#         job_id
# 0   4290796891
# 1   4259114971
# 2   4220839450
# 3   3849501886
# 4   3627622884
# 5   4292967130
# 6   4260012242
# 7   4255094324
# 8   4259098167
# 9   4259116372
# 10  4048230355
# 11  4276958556
# 12  4273221487
# 13  4240914500
# 14  4281485208
# 15  4287361545
# 16  4275350664
# 17  4168111890
# 18  4294061622
# 19  4244771461
# 20  4258065248
# 21  4267461418
# 22  4282530309
# 23  4204756249
# 24  4240915365
# 25  4295334909
# 26  4048228635
# 27  4261493690
# 28  4278553667
# 29  4282834220
# 30  4274643866
# 31  4274641859
# 32  4259095678
# 33  4293772062
# 34  4193362955
# 35  4292567427
# 36  4190532210
# 37  4189885322
# 38  4294838113
# 39  4273381368
# 40  4273385083
# 41  4273386060
# 42  4263992402
# 43  4273384149
# 44  4291154278
# 45  4281093212
# 46  4295167685
# 47  4273379435
# 48  4273379444
# 49  4273386061
# 50  4273381377
# 51  4273382291
# 52  4287397373
# 53  4281091343
# 54  4273380382
# 55  4273378985
# 56  4267225737
# 57  4255398471
# 58  4294396741
# 59  4273385077
